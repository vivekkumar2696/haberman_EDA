# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
harman_df = pd.read_csv("haberman.csv")

# %%
harman_df.head()
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1

# %%
harman_df.shape
# Out:
# (306, 4)

# %%
harman_df.columns
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
harman_df.status.value_counts()
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %%
sns.set_style("whitegrid");
sns.FacetGrid(harman_df, hue = "status", size = 4).map(plt.scatter, "nodes", "age").add_legend()

# %% [markdown]
# # Pair Plot

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(harman_df, hue="status", size = 3, vars=['age','nodes','year'])
plt.show()

# %% [markdown]
# Observations:-
# 1. In plot 3, between age and year, there are some overlap but this is better than the others
# 2. It is very difficult to find lines and if else conditions based on the plots

# %% [markdown]
# # 1D Scatter Plot

# %%
haberman_survive = harman_df.loc[harman_df['status'] == 1]
haberman_not_survive = harman_df.loc[harman_df['status'] == 2]
plt.plot(haberman_survive["nodes"], np.zeros_like(haberman_survive['nodes']), 'o')
plt.plot(haberman_not_survive["nodes"], np.zeros_like(haberman_not_survive['nodes']), 'o')
plt.show()

# %% [markdown]
# Observations:-
# Due to overlap of `survival` and `no survival`, it is difficult to deduce anything

# %%
# PDF of `nodes`
sns.FacetGrid(harman_df, hue = "status", size = 6) \
   .map(sns.distplot,"nodes") \
   .add_legend()

# %% [markdown]
# Observation:-
# 1. If the number of nodes are less, the chances of surivival is more
# 2. If Auxilary <= 0, survive,
# 3. else if auxilary > 0 and < 4~, chances of surviving is high
# 4. else will not survive

# %%
# PDF age
sns.FacetGrid(harman_df, hue = "status", size = 8) \
   .map(sns.distplot,"age") \
   .add_legend()

# %% [markdown]
# Mostly overlapping, difficult to predict anything

# %%
# PDF
sns.FacetGrid(harman_df, hue = "status", size = 8) \
   .map(sns.distplot,"year") \
   .add_legend()

# %% [markdown]
# Mostly overlapping, difficult to predict anything

# %%
haberman_long_survive = harman_df[harman_df['status'] == 1]
haberman_short_survive = harman_df[harman_df['status'] == 2]

# %%
# CDF
counts, bin_edges = np.histogram(haberman_long_survive['nodes'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(counts, bin_edges)
print(len(counts), len(bin_edges))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
print(cdf)
plt.plot(bin_edges[1:],pdf, label='pdf of patients who Surive More Than 5 years');
plt.plot(bin_edges[1:], cdf, label='cdf of patients who Surive More Than 5 years')

counts, bin_edges = np.histogram(haberman_short_survive['nodes'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(counts, bin_edges)
print(len(counts), len(bin_edges))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
print(cdf)
plt.plot(bin_edges[1:],pdf, label='pdf of patients who Surive Less Than 5 years');
plt.plot(bin_edges[1:], cdf, label='cdf of patients who Surive Less Than 5 years')

plt.legend(loc='best', bbox_to_anchor=(2.0, 0.8),title='Survival_status', fontsize='large')

plt.show();
# Out:
# [ 0.18164251  0.0173913   0.00483092  0.0057971   0.00386473  0.00096618
#   0.00193237  0.          0.          0.00096618] [  0.    4.6   9.2  13.8  18.4  23.   27.6  32.2  36.8  41.4  46. ]
# 10 11
# [ 0.83555556  0.08        0.02222222  0.02666667  0.01777778  0.00444444
#   0.00888889  0.          0.          0.00444444]
# [  0.    4.6   9.2  13.8  18.4  23.   27.6  32.2  36.8  41.4  46. ]
# [ 0.83555556  0.91555556  0.93777778  0.96444444  0.98222222  0.98666667
#   0.99555556  0.99555556  0.99555556  1.        ]
# [ 0.10921178  0.02849003  0.02611586  0.00949668  0.01424501  0.
#   0.00237417  0.          0.          0.00237417] [  0.    5.2  10.4  15.6  20.8  26.   31.2  36.4  41.6  46.8  52. ]
# 10 11
# [ 0.56790123  0.14814815  0.13580247  0.04938272  0.07407407  0.
#   0.01234568  0.          0.          0.01234568]
# [  0.    5.2  10.4  15.6  20.8  26.   31.2  36.4  41.6  46.8  52. ]
# [ 0.56790123  0.71604938  0.85185185  0.90123457  0.97530864  0.97530864
# ...

# %% [markdown]
# 1. There is a 90% chance that the person will live more than years if the nodes are less that 10 from yellow line(CDF of survive more than 5).
# 2. There is a 55% chance that the person will not survive if the nodes are near 5 from red line.

# %% [markdown]
# # Mean, Std, Variance

# %%
print("Mean of short lived:", np.mean(haberman_short_survive['nodes']))
print("Mean of long lived:", np.mean(haberman_long_survive['nodes']))

print("Mean of long lived with an outlier", np.mean(np.append(haberman_long_survive["nodes"],50)))

print("Std of short lived:", np.std(haberman_short_survive['nodes']))
print("Std of long lived:", np.std(haberman_long_survive['nodes']))
# Out:
# Mean of short lived: 7.45679012345679
# Mean of long lived: 2.7911111111111113
# Mean of long lived with an outlier 3.0
# Std of short lived: 9.128776076761632
# Std of long lived: 5.857258449412131

# %% [markdown]
# # Median, Quantile, Percentile, IQR, MAD

# %%
#Median, Quantiles, Percentiles, IQR.
print("\nMedians:")
print(np.median(haberman_long_survive["nodes"]))
#Median with an outlier
print(np.median(np.append(haberman_long_survive["nodes"],50)));
print(np.median(haberman_short_survive["nodes"]))


print("\nQuantiles:")
print(np.percentile(haberman_long_survive["nodes"],np.arange(0, 100, 25)))
print(np.percentile(haberman_short_survive["nodes"],np.arange(0, 100, 25)))

print("\n90th Percentiles:")
print(np.percentile(haberman_long_survive["nodes"],90))
print(np.percentile(haberman_short_survive["nodes"],90))

from statsmodels import robust
print ("\nMedian Absolute Deviation")
print(robust.mad(haberman_long_survive["nodes"]))
print(robust.mad(haberman_short_survive["nodes"]))
# Out:
# Medians:
# 0.0
# 0.0
# 4.0
#
# Quantiles:
# [ 0.  0.  0.  3.]
# [  0.   1.   4.  11.]
#
# 90th Percentiles:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'petal_length'
#
# During handling of the above exception, another exception occurred:
#
# ...
